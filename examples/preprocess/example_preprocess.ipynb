# %%
import geopandas as gpd

from connectpt.preprocess import preprocess
from connectpt.preprocess import Modality
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/sashamorozov/Documents/Code/ConnectPT/.venv/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/sashamorozov/Documents/Code/ConnectPT/.venv/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
blocks = gpd.read_file("/Users/sashamorozov/Documents/Code/TNDP_buses/TNDP_buses/Amsterdam_data/blocks_amsterdam.geojson")

# %%
res, G = preprocess(blocks, [Modality.TRAM])
# Out:
# 2025-11-28 19:14:57.378 | INFO     | connectpt.preprocess.stops:aggregate_stops:235 - Automatically calculated distance_threshold: 45.00m
# 2025-11-28 19:15:11.905 | WARNING  | connectpt.preprocess.projection:project_stops_on_roads:74 - Removed 8 stops located farther than 70 m from roads

# %%
tram_stops, tram_time_mx, tram_graph = res[Modality.TRAM]

# %%
tram_stops
# Out:
#                  x             y  nodeID  is_stop  \
# 0    630606.574981  5.801475e+06       0     True
# 1    626073.769267  5.802478e+06       1     True
# 2    630678.805442  5.803210e+06       2     True
# 3    629737.402263  5.803658e+06       3     True
# 4    627896.620755  5.805098e+06       4     True
# ..             ...           ...     ...      ...
# 179  627500.389797  5.797819e+06     179     True
# 180  628823.584558  5.801358e+06     180     True
# 181  629083.783291  5.801321e+06     181     True
# 182  628832.632526  5.801597e+06     182     True
# 183  626360.884186  5.802141e+06     183     True
#
#                            geometry modality    x_coord     y_coord
# 0      POINT (630606.575 5801474.9)     tram  630606.57  5801474.90
# 1    POINT (626073.769 5802477.767)     tram  626073.77  5802477.77
# 2    POINT (630678.805 5803210.227)     tram  630678.81  5803210.23
# 3     POINT (629737.402 5803657.72)     tram  629737.40  5803657.72
# ...

# %%
tram_time_mx
# Out:
# array([['0.00', 'Inf', 'Inf', ..., 'Inf', 'Inf', 'Inf'],
#        ['Inf', '0.00', 'Inf', ..., 'Inf', 'Inf', '1.85'],
#        ['Inf', 'Inf', '0.00', ..., 'Inf', 'Inf', 'Inf'],
#        ...,
#        ['Inf', 'Inf', 'Inf', ..., '0.00', 'Inf', 'Inf'],
#        ['Inf', 'Inf', 'Inf', ..., 'Inf', '0.00', 'Inf'],
#        ['Inf', '1.85', 'Inf', ..., 'Inf', 'Inf', '0.00']],
#       shape=(184, 184), dtype='<U4')

# %%
import momepy

n,e = momepy.nx_to_gdf(tram_graph)
m = e.explore()
n.explore(m=m, color="red")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/sashamorozov/Documents/Code/ConnectPT/.venv/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/sashamorozov/Documents/Code/ConnectPT/.venv/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
# ...
